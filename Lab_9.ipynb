# %% [markdown]
# <a href="https://colab.research.google.com/github/241b180pra/Algolab2026/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def dijkstra(graph, start):
    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances


# ----------- USER INPUT -------------
graph = {}

n = int(input("Enter number of nodes: "))

for _ in range(n):
    node = input("Enter node name: ")
    graph[node] = {}

    m = int(input(f"Enter number of neighbors for {node}: "))

    for _ in range(m):
        neighbor = input("  Neighbor: ")
        weight = int(input("  Weight: "))
        graph[node][neighbor] = weight


start = input("Enter starting node: ")

# ----------- RUN DIJKSTRA ----------
result = dijkstra(graph, start)

# ----------- OUTPUT ---------------
print("\nShortest distances:")
for node in result:
    print(f"{start} -> {node} = {result[node]}")
# Out:
# Enter number of nodes: 6
# Enter node name: pui
# Enter number of neighbors for pui: 3
#   Neighbor: 4
#   Weight: 5
#   Neighbor: 2
#   Weight: 6
#   Neighbor: 3
#   Weight: 5
# Enter node name: gui
# Enter number of neighbors for gui: 4
#   Neighbor: 2
#   Weight: 3
#   Neighbor: 9
#   Weight: 5
#   Neighbor: 8
#   Weight: 1
#   Neighbor: 6
#   Weight: 4
# Enter node name: tui
# Enter number of neighbors for tui: 2
#   Neighbor: 3
#   Weight: 1
#   Neighbor: 7
#   Weight: 8
# Enter node name: mui
# Enter number of neighbors for mui: 3
#   Neighbor: 1
#   Weight: 26
#   Neighbor: 3
#   Weight: 35
#   Neighbor: 2
#   Weight: 26
# Enter node name: hui
# Enter number of neighbors for hui: 2
#   Neighbor: 32
#   Weight: 12
#   Neighbor: 26
#   Weight: 35
# Enter node name: chui
# Enter number of neighbors for chui: 2
#   Neighbor: 35
#   Weight: 26
#   Neighbor: 12
#   Weight: 35
# Enter starting node: 2
#
# Shortest distances:
# 2 -> pui = inf
# 2 -> gui = inf
# 2 -> tui = inf
# 2 -> mui = inf
# 2 -> hui = inf
# 2 -> chui = inf
# 2 -> 2 = 0

# %%
def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}
    visited = set()

    distances[start] = 0

    while len(visited) < len(graph):
        # Find unvisited node with smallest distance
        min_node = None
        min_distance = float('inf')
        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.add(min_node)

        # Update neighbors
        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous[neighbor] = min_node

    return distances, previous

# Function to reconstruct path
def get_path(previous, start, end):
    path = []
    current = end
    while current is not None:
        path.append(current)
        current = previous[current]
    path.reverse()
    if path[0] == start:
        return path
    else:
        return None  # no path

# ----------- USER INPUT -------------
graph = {}
n = int(input("Enter number of nodes: "))

for _ in range(n):
    node = input("Enter node name: ")
    graph[node] = {}
    m = int(input(f"Enter number of neighbors for {node}: "))
    for _ in range(m):
        neighbor = input("  Neighbor: ")
        weight = int(input("  Weight: "))
        graph[node][neighbor] = weight

start = input("Enter starting node: ")

# ----------- RUN DIJKSTRA ----------
distances, previous = dijkstra(graph, start)

# ----------- OUTPUT ---------------
print("\nShortest distances and paths:")
for node in graph:
    path = get_path(previous, start, node)
    if path:
        print(f"{start} -> {node} = {distances[node]}, Path: {' -> '.join(path)}")
    else:
        print(f"{start} -> {node} = ∞, Path: None")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_11915/1881843107.py in <cell line: 0>()
#      44 # ----------- USER INPUT -------------
#      45 graph = {}
# ---> 46 n = int(input("Enter number of nodes: "))
#      47
#      48 for _ in range(n):
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
